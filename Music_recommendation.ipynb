# %% [markdown]
# <a href="https://colab.research.google.com/github/801PEC/dataset-for-music-recommendation/blob/main/Music_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello everyone!
# This is a simple ***AI and ML project*** created by me as part of the ***AICTE internship***.
#
# This is a ***Lyrics-based Music Recommendation System***. It recommends songs based on the words and content of their lyrics
#
# I used a data set form Kaggle Data Set
# DataSet Link:-https://www.kaggle.com/datasets/notshrirang/spotify-million-song-dataset/data
#
# My GitHub link for the dataset:-https://github.com/801PEC/dataset-for-music-recommendation
#
# Its a simple data set and contains only 4 columns.
#
# I have mostly given comments to run it for yourself
#
# ***Important*** `(Please Read)`
#
# I have made it so that , it downloads the data set from my github repo
# so you dont have to login with your kaggle id.
#
# The ML model will work until the recommandation of the song as list....
#
# But the code blocks after that , consisting of the Web API will only run if you give the api key for spotify which you can get it form the ***spotifiy developers*** website and also ***ngrok api key*** should also be genrated and given For the website or web app to work!

# %% [markdown]
# ### ***Importing the Main Libraries***

# %%
# !pip install opendatasets

# %%
import pandas as pd
import opendatasets as od
import os

# %% [markdown]
# ### ***Importing the DataSet from GitHub and Viewing it***

# %%
# !git lfs install
# !git clone https://github.com/801PEC/dataset-for-music-recommendation
# Out:
# Git LFS initialized.
# Cloning into 'dataset-for-music-recommendation'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.

# %%
train_df = pd.read_csv('/content/dataset-for-music-recommendation/spotify_millsongdata.csv')

# %%
train_df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
train_df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %% [markdown]
# ### ***Checking For Null Values***

# %%
train_df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %% [markdown]
# ***No Null Value***

# %% [markdown]
# ### ***Droping the coloumns which we dont need***

# %%
train_df = train_df.drop('link', axis=1).reset_index(drop=True)

# %%
train_df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %% [markdown]
# ### ***Lowering the Traning Data, So we can train the model easily***

# %%
low_train_df = train_df.sample(5000).reset_index(drop=True)

# %%
low_train_df.shape
# Out:
# (5000, 3)

# %%
low_train_df
# Out:
#              artist               song  \
# 0         Kari Jobe   Stars In The Sky
# 1              Korn              Daddy
# 2          Westlife        Uptown Girl
# 3          Flo-Rida          Be On You
# 4           Ramones        Danger Zone
# ...             ...                ...
# 4995  Willie Nelson       Born To Lose
# 4996         Pogues        Blue Heaven
# 4997    Bing Crosby              Dinah
# 4998       Children     Rise And Shine
# 4999    Proclaimers  She Arouses Me So
#
#                                                    text
# 0     Take the sun  \r\nTake the moon  \r\nTake the ...
# 1     Mother please forgive me  \r\nI just had to ge...
# 2     Uptown girl  \r\nShe's been living in her upto...
# 3     I said excuse me little mama if I may  \r\nTak...
# 4     New York city is a real cool town  \r\nSociety...
# ...                                                 ...
# 4995  I'm born to lose  \r\nI've lived my life in va...
# ...

# %% [markdown]
# ### ***Handling Lyrics , by removeing special characters(ex:-/r,/n) , Single character(ex:-A,I) and lowering all the letters***

# %%
low_train_df['text'][0]
# Out:
# "Take the sun  \r\nTake the moon  \r\nTake the earth and watch it move  \r\nUnder Your control  \r\nCause You're all I know  \r\n  \r\nHere's my life and all my heart  \r\nI give it all but every part  \r\nIs under Your control  \r\nLord You're all I know  \r\n  \r\n[Chorus]  \r\nThe stars in the sky will hang there  \r\n'til You tell them to  \r\nThe faith in my heart will still sing  \r\nOf what Your love can do  \r\nAnd even when life weighs heavy on me  \r\nI know You're in control  \r\nAnd You're all I need  \r\nThe stars in the sky will hang there  \r\n'til You tell them to  \r\n  \r\nTake the sea  \r\nTake the tide  \r\nTake the waters watch them rise  \r\nGiving praise to You  \r\nAlways praising You  \r\nHere's my voice  \r\nAnd all my soul  \r\nSinging freely when  \r\nLord, I'm giving praise to You  \r\nLord I'm praising You  \r\n  \r\n[Chorus]  \r\n  \r\nThe clouds will rain  \r\nThe seasons change  \r\n(Cause You told them to)  \r\nThe sun will shine  \r\nYour burning li
# ...

# %%
 low_train_df['text'] = low_train_df['text'].str.lower().replace(r'^\w\s',' ').replace(r'\n',' ',regex=True).replace(r"\r",' ',regex=True)

# %%
low_train_df['text'][0]
# Out:
# "take the sun    take the moon    take the earth and watch it move    under your control    cause you're all i know        here's my life and all my heart    i give it all but every part    is under your control    lord you're all i know        [chorus]    the stars in the sky will hang there    'til you tell them to    the faith in my heart will still sing    of what your love can do    and even when life weighs heavy on me    i know you're in control    and you're all i need    the stars in the sky will hang there    'til you tell them to        take the sea    take the tide    take the waters watch them rise    giving praise to you    always praising you    here's my voice    and all my soul    singing freely when    lord, i'm giving praise to you    lord i'm praising you        [chorus]        the clouds will rain    the seasons change    (cause you told them to)    the sun will shine    your burning light    (cause you told it to)    when you speak your words through my soul    
# ...

# %% [markdown]
# ### ***Tokenization and Stemmer***
#
# Explanation:-
# Tokenization is the process of breaking a text into smaller parts called tokens.
# ```
# Original text: "I love music."
# After tokenization: ["I", "love", "music", "."]
# ```
# Stemming is the process of reducing a word to its root form.
# ```
# Words: "playing", "played", "plays"
# After stemming: "play"
# ```

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('punkt')
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#Tokenization
def token(txt):
  token = nltk.word_tokenize(txt)
  a = [stemmer.stem(w) for w in token]
  return " ".join(a)

# %%
#example
token("you are playing , played plays")
# Out:
# 'you are play , play play'

# %%
low_train_df['text'] = low_train_df['text'].apply(lambda x: token(x))

# %%
low_train_df
# Out:
#              artist               song  \
# 0         Kari Jobe   Stars In The Sky
# 1              Korn              Daddy
# 2          Westlife        Uptown Girl
# 3          Flo-Rida          Be On You
# 4           Ramones        Danger Zone
# ...             ...                ...
# 4995  Willie Nelson       Born To Lose
# 4996         Pogues        Blue Heaven
# 4997    Bing Crosby              Dinah
# 4998       Children     Rise And Shine
# 4999    Proclaimers  She Arouses Me So
#
#                                                    text
# 0     take the sun take the moon take the earth and ...
# 1     mother pleas forgiv me i just had to get out a...
# 2     uptown girl she 's been live in her uptown wor...
# 3     i said excus me littl mama if i may take thi t...
# 4     new york citi is a real cool town societi real...
# ...                                                 ...
# 4995  i 'm born to lose i 've live my life in vain e...
# ...

# %% [markdown]
# ### ***Vectorization***
# Vectorization means converting text data into numerical form (vectors) so that machine learning models can understand and process it.
# ```
# Sentences:
# 1. "I love music"
# 2. "I hate music"
#
# Vocabulary: ["I", "love", "hate", "music"]
#
# Vector for Sentence 1: [1, 1, 0, 1]
# Vector for Sentence 2: [1, 0, 1, 1]
#
# ```
# Once texts are converted into vectors, we need a way to measure how similar they are.
#
# Cosine Similarity measures the angle between two vectors. The smaller the angle, the more similar the texts.
#
# For example:- Lets say the Cosine Similarity between two sentences is 1 then the sentence are Verysimilar to ecah other , if the Cosine Similarity is 0.5 then they are 50% similar to each other (Maybe they contain some common words), if it is 0, they are completely different.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfid = TfidfVectorizer(analyzer='word', stop_words='english')

# %%
matrix = tfid.fit_transform(low_train_df['text'])

# %%
similarity = cosine_similarity(matrix)

# %%
similarity[0]
# Out:
# array([1.        , 0.01379004, 0.01552869, ..., 0.0130371 , 0.10025026,
#        0.00773452])

# %%
low_train_df[low_train_df['song']=='Haunted'].index[0]
# Out:
# np.int64(4155)

# %% [markdown]
# ### ***Recommendation Function***

# %%
def recommendor(song_name):
  idx = low_train_df[low_train_df['song']==song_name].index[0]
  distance = sorted(list(enumerate(similarity[idx])),reverse=True,key=lambda x:x[1])
  song = []
  for s_id in distance[1:6]:
    song.append(low_train_df.iloc[s_id[0]].song)
  return song

# %%
recommendor('Stars In The Sky')
# Out:
# ['Even When It Hurts (Praise Song)',
#  'Everything That Has Breath',
#  'I Will',
#  'Give Him Praise',
#  "Can't Stop Praising"]

# %% [markdown]
# > ***Hence , The model is sucessfully compelted and working , the rest code is for the web application which you can explore if you want to***

# %% [markdown]
# ### ***WebApplication Exporting***
#
# Here you need to give both Spotify developer key and id and ngrok token or else it will not run
#
# Spotify Developer:-https://developer.spotify.com/
#
# ngrok:https://dashboard.ngrok.com/get-started/your-authtoken

# %%
import pickle

# %%
pickle.dump(similarity, open('similarity.pkl','wb'))
pickle.dump(low_train_df, open('low_train_df.pkl','wb'))

# %%
# !ls
# Out:
# dataset-for-music-recommendation  low_train_df.pkl  sample_data  similarity.pkl

# %%
# !pip install streamlit pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 109.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 107.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.4 MB/s eta 0:00:00
# ...

# %%
# !pip install spotipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.7/278.7 kB 18.8 MB/s eta 0:00:00
# ...

# %%
# %%writefile app.py
import pickle
import streamlit as st
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

CLIENT_ID = "GIVE YOUR CLIENT ID FROM SPOTIFY DEVELOPERS HERE"
CLIENT_SECRET = "GIVE YOUR CLIENT SECRET FROM SPOTIFY DEVELOPERS HERE"

client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_song_album_cover_url(song_name, artist_name):
    search_query = f"track:{song_name} artist:{artist_name}"
    results = sp.search(q=search_query, type="track")

    if results and results["tracks"]["items"]:
        track = results["tracks"]["items"][0]
        album_cover_url = track["album"]["images"][0]["url"]
        print(album_cover_url)
        return album_cover_url
    else:
        return "https://i.postimg.cc/0QNxYz4V/social.png"

def recommend(song):
    index = music[music['song'] == song].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    recommended_music_names = []
    recommended_music_posters = []
    for i in distances[1:6]:

        artist = music.iloc[i[0]].artist
        print(artist)
        print(music.iloc[i[0]].song)
        recommended_music_posters.append(get_song_album_cover_url(music.iloc[i[0]].song, artist))
        recommended_music_names.append(music.iloc[i[0]].song)

    return recommended_music_names,recommended_music_posters

st.header('Music Recommender System')
music = pickle.load(open('low_train_df.pkl','rb'))
similarity = pickle.load(open('similarity.pkl','rb'))

music_list = music['song'].values
selected_movie = st.selectbox(
    "Type or select a song from the dropdown",
    music_list
)

if st.button('Show Recommendation'):
    recommended_music_names,recommended_music_posters = recommend(selected_movie)
    col1, col2, col3, col4, col5= st.columns(5)
    with col1:
        st.text(recommended_music_names[0])
        st.image(recommended_music_posters[0])
    with col2:
        st.text(recommended_music_names[1])
        st.image(recommended_music_posters[1])

    with col3:
        st.text(recommended_music_names[2])
        st.image(recommended_music_posters[2])
    with col4:
        st.text(recommended_music_names[3])
        st.image(recommended_music_posters[3])
    with col5:
        st.text(recommended_music_names[4])
        st.image(recommended_music_posters[4])
# Out:
# Writing app.py

# %%
#RE-RUN THIS CODE IF IT GIVES ERROR

from pyngrok import ngrok
from pyngrok import ngrok


ngrok.set_auth_token("GIVE YOUR TON FROM NGROK HERE")

ngrok.kill()


get_ipython().system_raw("streamlit run app.py &")


public_url = ngrok.connect(8501)
print("🔗 Public URL:", public_url)
# Out:
# 🔗 Public URL: NgrokTunnel: "https://2381-35-194-92-22.ngrok-free.app" -> "http://localhost:8501"
